# %% [markdown]
# # Python Essentials Practice
# Welcome! Complete each task below to strengthen your understanding of Python basics: variables, conditions, loops, and data structures.
# Read the instructions carefully and use the code cells that follow to write your solutions.

# %% [markdown]
# ## Task 1 · Variables
# 1. Create variables for your name (string), age (integer), and height in meters (float).
# 2. Print a sentence that introduces yourself using all three variables.
# 3. Update the age variable to represent your age next year and print the updated sentence.

# %%
# Write your Task 1 solution here.
# Create the variables, build the message, and display the results.

# %% [markdown]
# ## Task 2 · Conditions
# 1. Ask the user for an integer using `input()` and convert it to an `int`.
# 2. If the number is even, print a message saying it is even; otherwise print that it is odd.
# 3. Extend the message to mention when the number is greater than 10.

# %%
# Write your Task 2 solution here.
# Remember to handle user input and cover both conditions.

# %% [markdown]
# ## Task 3 · Loops
# 1. Create a list containing five numbers of your choice.
# 2. Use a `for` loop to print each number together with its square.
# 3. Use a `while` loop that keeps asking the user for numbers until they enter `0`. When the loop ends, print the total sum of the numbers entered (excluding the final zero).

# %%
# Write your Task 3 solution here.
# Use both a for loop and a while loop as described.

# %% [markdown]
# ## Task 4 · Data Structures
# 1. Create a list named `students` that holds at least three dictionaries. Each dictionary should include `name`, `age`, and `favorite_color`.
# 2. Loop over the list and print a friendly sentence for each student.
# 3. Add a new student to the list and show that the list contains the new entry.
# 4. Bonus: build a set of all unique favorite colors and print it.

# %%
# Write your Task 4 solution here.
# Work with lists, dictionaries, and sets to complete the instructions.

# %% [markdown]
# ## Reflection
# - Re-run each cell to make sure your code works as expected.
# - Note any Python concepts that still feel unclear and prepare questions for our next session.
# - If you finish early, try modifying your solutions to add new features or handle unexpected input.
