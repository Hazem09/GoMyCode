# %% [markdown]
# # Pandas Practice Exercises
# These exercises help you practise foundational Pandas operations. Work through each prompt in the paired code cell and test your answers to confirm they behave as expected.

# %%
import pandas as pd

# %% [markdown]
# ## Exercise 1: Create a Series
# Convert the Python list `["Alice", "Bob", "Carlos"]` into a Pandas Series and display the result along with its index.
#
# Example structure:
# ```python
# names = [...]  # Use the provided list
# series = pd.Series(names)
# print(series)
# print(series.index)
# ```

# %% [markdown]
# ## Exercise 2: Create a DataFrame
# Build a DataFrame from the dictionary `{"Name": ["Ali", "Mira", "Ziad"], "Score": [88, 92, 79]}` and display the table.
#
# Example structure:
# ```python
# data = {...}  # Insert the provided dictionary
# df = pd.DataFrame(data)
# print(df)
# ```

# %% [markdown]
# ## Exercise 3: Select a Single Column
# Using the DataFrame from Exercise 2, select the `Score` column with square brackets and store it in a variable.
#
# Example structure:
# ```python
# scores = df[...]
# print(scores)
# ```

# %% [markdown]
# ## Exercise 4: Select Multiple Columns
# Select the `Name` and `Score` columns together using a double-square-bracket selection and display the resulting DataFrame.
#
# Example structure:
# ```python
# name_score = df[[... , ...]]
# print(name_score)
# ```

# %% [markdown]
# ## Exercise 5: Select Rows by Label with `loc`
# Assign the row labels `['student_1', 'student_2', 'student_3']` to the DataFrame's index. Then select the row labeled `student_2` using `.loc`.
#
# Example structure:
# ```python
# df.index = [..., ..., ...]
# student_two = df.loc[...]
# print(student_two)
# ```

# %% [markdown]
# ## Exercise 6: Select Rows and Columns by Label with `loc`
# Using the labeled index from Exercise 5, select the `Score` and `Name` columns for rows `student_1` and `student_3` via `.loc`.
#
# Example structure:
# ```python
# subset = df.loc[[..., ...], [..., ...]]
# print(subset)
# ```

# %% [markdown]
# ## Exercise 7: Select Rows by Position with `iloc`
# Select the second row (index position 1) from the DataFrame using `.iloc` and display the result.
#
# Example structure:
# ```python
# second_row = df.iloc[...]
# print(second_row)
# ```

# %% [markdown]
# ## Exercise 8: Select Rows and Columns by Position with `iloc`
# Using `.iloc`, select rows at positions 0 and 2 and the column at position 1. Display the resulting DataFrame.
#
# Example structure:
# ```python
# subset = df.iloc[[..., ...], [...]]
# print(subset)
# ```
