# %% [markdown]
# ## Part 1: Recursion
#
# Recursion occurs when a function calls itself to solve a smaller instance of the problem.

# %% [markdown]
# ### Task 1: Iterative Factorial
# **Goal:** Write a function `factorial_iterative(n)` that calculates the factorial of a number using a standard loop (`for` or `while`).
#
# **Instructions:**
# 1. Define the function taking `n` as input.
# 2. Initialize a result variable to 1.
# 3. Loop from 1 to `n` (inclusive) and multiply the result by the current number.
# 4. Return the result.
# 5. Test it with `n=5`.

# %%
def factorial_iterative(n):
	# your code here
	pass

# Test the function
print(factorial_iterative(5))

# %% [markdown]
# ### Task 2: Recursive Factorial
# **Goal:** Write a function `factorial_recursive(n)` that calculates the factorial by calling itself.
#
# **Instructions:**
# 1. **Base Case:** If `n` is 0 or 1, return 1.
# 2. **Recursive Step:** Return `n * factorial_recursive(n - 1)`.
# 3. **Visualization:** Add `print(f"Calculating factorial for {n}")` at the very start of the function. This will show you the order of function calls.
# 4. Test it with `n=5`.

# %%
def factorial_recursive(n):
# your code here
	pass

# Test the function
print(f"Result: {factorial_recursive(5)}")

# %% [markdown]
# ## Part 2: Binary Search
#
# Binary search is an efficient algorithm for finding an item from a **sorted** list of items. It works by repeatedly dividing in half the portion of the list that could contain the item.

# %% [markdown]
# ### Task 3: Recursive Binary Search
# **Goal:** Implement binary search recursively to find a target number in a sorted list.
#
# **Data:** `[2, 5, 8, 12, 16, 23, 38, 56, 72, 91]`
#
# **Instructions:**
# 1. Define `binary_search(arr, target, start, end)`.
# 2. **Visualization:** Inside the function, print the current `start`, `end`, and `mid` indices to see how the search window shrinks.
# 3. Calculate `mid` index.
# 4. **Base Case:** If `start > end`, the target is not found (return -1).
# 5. Check if `arr[mid]` is the target. If yes, return `mid`.
# 6. If `arr[mid] > target`, search the left half (call function with `end = mid - 1`).
# 7. If `arr[mid] < target`, search the right half (call function with `start = mid + 1`).

# %%
my_list = [2, 5, 8, 12, 16, 23, 38, 56, 72, 91]
target = 23

def binary_search(arr, target, start, end):
	# your code here
	pass
result = binary_search(my_list, target, 0, len(my_list) - 1)

print(f"Target found at index: {result}")

# %% [markdown]
# ## Part 3: Sorting Algorithms
#
# We will explore three common sorting algorithms: Bubble Sort, Merge Sort, and Quick Sort.

# %% [markdown]
# ### Task 4: Bubble Sort
# **Goal:** Implement Bubble Sort, a simple sorting algorithm that repeatedly steps through the list, compares adjacent elements and swaps them if they are in the wrong order.
#
# **Data:** `[64, 34, 25, 12, 22, 11, 90]`
#
# **Instructions:**
# 1. Define `bubble_sort(arr)`.
# 2. Use nested loops. The outer loop runs `n` times. The inner loop runs `n-i-1` times.
# 3. Inside the inner loop, compare `arr[j]` and `arr[j+1]`. Swap them if `arr[j] > arr[j+1]`.
# 4. **Visualization:** Inside the **outer** loop (after the inner loop finishes a pass), print the current state of the list: `print(f"After pass {i}: {arr}")`.

# %%
unsorted_list = [64, 34, 25, 12, 22, 11, 90]

def bubble_sort(arr):
    n = len(arr)
    # Your code here
    pass

bubble_sort(unsorted_list)
print(f"Final Sorted List: {unsorted_list}")

# %% [markdown]
# ### Task 5: Merge Sort
# **Goal:** Implement Merge Sort, a divide-and-conquer algorithm that divides the input array into two halves, calls itself for the two halves, and then merges the two sorted halves.
#
# **Instructions:**
# 1. Define `merge_sort(arr)`.
# 2. **Base Case:** If `len(arr) > 1`:
#     - Find the middle index.
#     - Create `left_half` and `right_half` lists.
#     - Recursively call `merge_sort` on both halves.
#     - **Visualization:** Before the merging logic begins, print the two halves being merged: `print(f"Merging {left_half} and {right_half}")`.
#     - Implement the logic to merge the sorted halves back into `arr`.

# %%
unsorted_list_2 = [38, 27, 43, 3, 9, 82, 10]

def merge_sort(arr):
    # Your code here
    pass

merge_sort(unsorted_list_2)
print(f"Final Sorted List: {unsorted_list_2}")

# %% [markdown]
# ### Task 6: Quick Sort
# **Goal:** Implement Quick Sort, which picks an element as a pivot and partitions the given array around the picked pivot.
#
# **Instructions:**
# 1. Define `quick_sort(arr)`.
# 2. **Base Case:** If `len(arr) <= 1`, return `arr`.
# 3. **Pivot Selection:** Choose the last element as the pivot.
# 4. **Visualization:** Print the chosen pivot: `print(f"Pivot chosen: {pivot}")`.
# 5. **Partitioning:** Create two lists:
#     - `left`: elements smaller than pivot.
#     - `right`: elements greater than pivot.
# 6. **Recursive Step:** Return `quick_sort(left) + [pivot] + quick_sort(right)`.

# %%
unsorted_list_3 = [10, 7, 8, 9, 1, 5]

def quick_sort(arr):
    # Your code here
    pass

sorted_list = quick_sort(unsorted_list_3)
print(f"Final Sorted List: {sorted_list}")
